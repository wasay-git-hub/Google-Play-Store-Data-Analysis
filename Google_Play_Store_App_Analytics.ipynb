# %% [markdown]
# <a href="https://colab.research.google.com/github/wasay-git-hub/Google-Play-Store-Data-Analysis/blob/main/Google_Play_Store_App_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# 0   July 28, 2017          4.1 and up
# 1  April 15, 2016          3.0 and up
# 2   July 11, 2018          4.2 and up
# 3   June 28, 2018  Varies with device
# 4  August 6, 2018          4.1 and up

# %%
df_apps.sample(n=3)
# Out:
#                              App       Category  Rating  Reviews  Size_MBs  \
# 4586          Free Wi-fi HotspoT  COMMUNICATION    4.10      382      2.30
# 2466  ReactNative BG Geolocation          TOOLS    5.00        5      9.10
# 9199          Grand Gangsters 3D           GAME    4.20   401643     36.00
#
#         Installs  Type Price Content_Rating         Genres   Last_Updated  \
# 4586      50,000  Free     0       Everyone  Communication  July 20, 2018
# 2466       1,000  Free     0       Everyone          Tools   May 25, 2018
# 9199  10,000,000  Free     0           Teen         Action  July 18, 2018
#
#              Android_Ver
# 4586          4.0 and up
# 2466          4.1 and up
# 9199  Varies with device

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.tail()
# Out:
#                   App Category  Rating   Reviews  Size_MBs       Installs  \
# 10836  Subway Surfers     GAME    4.50  27723193     76.00  1,000,000,000
# 10837  Subway Surfers     GAME    4.50  27724094     76.00  1,000,000,000
# 10838  Subway Surfers     GAME    4.50  27725352     76.00  1,000,000,000
# 10839  Subway Surfers     GAME    4.50  27725352     76.00  1,000,000,000
# 10840  Subway Surfers     GAME    4.50  27711703     76.00  1,000,000,000
#
#        Type Price Content_Rating  Genres   Last_Updated Android_Ver
# 10836  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10837  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10838  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10839  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10840  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps_clean = df_apps.dropna()

# %%
df_apps_clean.isnull().values.any()
# Out:
# np.False_

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839     True
# 10840    False
# Length: 10841, dtype: bool

# %%
instagram_rows = df_apps[df_apps['App']=='Instagram']
instagram_rows.duplicated().any()
# Out:
# np.True_

# %%
instagram_rows.duplicated().sum()
# Out:
# np.int64(1)

# %%
instagram_rows[instagram_rows.duplicated()]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres   Last_Updated         Android_Ver
# 10809     0           Teen  Social  July 31, 2018  Varies with device

# %%
df_apps_clean.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
highest_rated = df_apps_clean.sort_values(by='Rating', ascending=False)
highest_rated.head()
# Out:
#                                       App            Category  Rating  \
# 2375  The Divine Feminine App: the DF App           LIFESTYLE    5.00
# 436                         Chronolink DX              FAMILY    5.00
# 453                   Wowkwis aq Ka'qaquj              FAMILY    5.00
# 462                                CB Fit  HEALTH_AND_FITNESS    5.00
# 186                Basics of Orthopaedics             MEDICAL    5.00
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating  \
# 2375        8      6.70    1,000  Free      0       Everyone
# 436         7     73.00       10  Paid  $0.99       Everyone
# 453         1     49.00       10  Free      0       Everyone
# 462         1      7.80       10  Free      0       Everyone
# 186         1      5.60       10  Free      0       Everyone
#
#                    Genres       Last_Updated   Android_Ver
# 2375            Lifestyle       May 16, 2016    4.1 and up
# 436                Puzzle       July 6, 2017    4.1 and up
# 453   Education;Education  February 16, 2018  4.0.3 and up
# 462      Health & Fitness       July 9, 2018    4.1 and up
# 186               Medical      July 27, 2018    4.1 and up

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
largest = df_apps_clean.sort_values(by='Size_MBs', ascending=False)
largest.head()
# Out:
#                                                     App Category  Rating  \
# 7928                      Stickman Legends: Shadow Wars     GAME    4.40
# 8719                         Draft Simulator for FUT 18   SPORTS    4.60
# 10295                                   SimCity BuildIt   FAMILY    4.50
# 8718                  Mini Golf King - Multiplayer Game     GAME    4.50
# 4176   Car Crash III Beam DH Real Damage Simulator 2018     GAME    3.60
#
#        Reviews  Size_MBs    Installs  Type  Price Content_Rating      Genres  \
# 7928     38419    100.00   1,000,000  Paid  $0.99   Everyone 10+      Action
# 8719    162933    100.00   5,000,000  Free      0       Everyone      Sports
# 10295  4218587    100.00  50,000,000  Free      0   Everyone 10+  Simulation
# 8718    531458    100.00   5,000,000  Free      0       Everyone      Sports
# 4176       151    100.00      10,000  Free      0       Everyone      Racing
#
#          Last_Updated   Android_Ver
# 7928   August 3, 2018    4.1 and up
# 8719     May 11, 2018    4.1 and up
# 10800            Communication  August 1, 2018  Varies with device
# 10784            Communication  August 1, 2018  Varies with device
# 10652                 Strategy   July 15, 2018          4.1 and up
# 10650                 Strategy   July 15, 2018          4.1 and up
# 10651                 Strategy   July 15, 2018          4.1 and up
# 10653                 Strategy   July 15, 2018          4.1 and up
# 10744                    Tools  August 3, 2018  Varies with device
# 10839                   Arcade   July 12, 2018          4.1 and up
# 10838                   Arcade   July 12, 2018          4.1 and up
# 10837                   Arcade   July 12, 2018          4.1 and up
# 10836                   Arcade   July 12, 2018          4.1 and up
# 10835                   Arcade   July 12, 2018          4.1 and up
# 10840                   Arcade   July 12, 2018          4.1 and up
# 10828  Video Players & Editors  August 2, 2018  Varies with device
# 10830  Video Players & Editors  August 2, 2018  Varies with device
# 10746                    Tools  August 4, 2018  Varies with device
# 10588                 Strategy   June 27, 2018          4.1 and up
# 10586                 Strategy   June 27, 2018          4.1 and up
# 10584                 Strategy   June 27, 2018          4.1 and up
# 10592                 Strategy   June 27, 2018          4.1 and up
# 10768                   Casual    July 5, 2018          4.1 and up
# 10767                   Casual    July 5, 2018          4.1 and up
# 10766                   Casual    July 5, 2018          4.1 and up
# 10764                   Casual    July 5, 2018          4.1 and up
# 10765                   Casual    July 5, 2018          4.1 and up
# 10763                   Casual    July 5, 2018          4.1 and up
# 10769                   Casual    July 5, 2018          4.1 and up
# 10771            Communication  August 2, 2018          4.0 and up
# 10770            Communication  August 2, 2018          4.0 and up
# 10772            Communication  August 2, 2018          4.0 and up
# 10737                   Social   July 30, 2018  Varies with device
# 10735                   Social   July 30, 2018  Varies with device
# 10736                   Social   July 30, 2018  Varies with device
# 10738                   Social   July 30, 2018  Varies with device
# 10489                    Tools  August 4, 2018  Varies with device
# 10732                   Casual   July 19, 2018          4.1 and up
# 10731                   Casual   July 19, 2018          4.1 and up
# 10733                   Casual   July 19, 2018          4.1 and up
# 10599                   Sports   July 31, 2018        4.0.3 and up
# 10600                   Sports   July 31, 2018        4.0.3 and up

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean['Content_Rating'].value_counts()
ratings
# Out:
# Content_Rating
# Everyone           7419
# Teen               1084
# Mature 17+          461
# Everyone 10+        397
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
figure = px.pie(ratings, names=ratings.index,values=ratings.values, title='Content Ratings of apps', hole=0.5)
figure.update_traces(textfont_size=15)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d9696ab8-61fc-43b0-98f7-46783a8f2709" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9696ab8-61fc-43b0-98f7-46783a8f2709")) {                    Plotly.newPlot(                        "d9696ab8-61fc-43b0-98f7-46783a8f2709",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Content_Rating=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[7419,1084,461,397,3,1],"type":"pie","textfont":{"size":15}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatt ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres      Last_Updated  \
# 21     25.00        1  Free      0       Everyone  Medical    August 2, 2018
# 28     20.00        1  Paid  $1.49       Everyone   Arcade  February 8, 2017
# 47     16.00        1  Paid  $0.99       Everyone   Arcade     March 3, 2017
# 82     19.00        5  Free      0       Everyone   Arcade     July 23, 2018
# 99      4.60        5  Free      0       Everyone  Medical    August 2, 2018
#
#      Android_Ver
# 21  4.0.3 and up
# 28    2.3 and up
# 47    2.3 and up
# 82    4.1 and up
# 99    4.0 and up

# %%
installs = df_apps_clean['Installs'].value_counts()
print(installs['1,000,000'])
print(installs['1'])
# Out:
# 1577
# 3

# %%
print(df_apps_clean['Installs'].dtype)
# Out:
# object

# %%
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#                 App
# Installs
# 1                 3
# 1,000           713
# 1,000,000      1577
# 1,000,000,000    58
# 10               69
# 10,000         1009
# 10,000,000     1252
# 100             309
# 100,000        1150
# 100,000,000     409
# 5                 9
# 5,000           432
# 5,000,000       752
# 50               56
# 50,000          467
# 50,000,000      289
# 500             201
# 500,000         538
# 500,000,000      72

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean["Price"] = df_apps_clean["Price"].astype(str).str.replace('$', '', regex=False)
df_apps_clean["Price"] = pd.to_numeric(df_apps_clean["Price"])
df_apps_clean.sort_values('Price', ascending=False).head(20)
# Out:
# /tmp/ipython-input-4245493992.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipython-input-4245493992.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 3897                       I Am Rich     FAMILY    3.60      217      4.90
# 2193             I am extremely Rich  LIFESTYLE    2.90       41      2.90
# 3856                   I am rich VIP  LIFESTYLE    3.80      411      2.60
# 2282       Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 2281       Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407                    LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629                I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2482         A Manual of Acupuncture    MEDICAL    3.50      214     68.00
#
#      Installs  Type  Price Content_Rating         Genres       Last_Updated  \
# 3946   10,000  Paid 400.00       Everyone      Lifestyle        May 3, 2018
# 3221   10,000  Paid 399.99       Everyone  Entertainment       May 19, 2018
# 5765  100,000  Paid 399.99       Everyone      Lifestyle   January 12, 2018
# 3145    5,000  Paid 399.99       Everyone        Finance        May 1, 2017
# 3114    5,000  Paid 399.99       Everyone        Finance     March 22, 2018
# 1331      100  Paid 399.99       Everyone  Entertainment      July 16, 2018
# 4606   50,000  Paid 399.99       Everyone        Finance  November 12, 2017
# 2461    1,000  Paid 399.99       Everyone        Finance      June 25, 2018
# 2394    1,000  Paid 399.99       Everyone        Finance  December 11, 2017
# 1946    1,000  Paid 399.99           Teen        Finance   December 6, 2017
# 2775    5,000  Paid 399.99       Everyone  Entertainment       May 30, 2017
# 3554   10,000  Paid 399.99       Everyone      Lifestyle     March 11, 2018
# 3897   10,000  Paid 389.99       Everyone  Entertainment      June 22, 2018
# 2193    1,000  Paid 379.99       Everyone      Lifestyle       July 1, 2018
# 3856   10,000  Paid 299.99       Everyone      Lifestyle      July 21, 2018
# 2282    1,000  Paid  79.99       Everyone        Medical      June 18, 2018
# 2281    1,000  Paid  79.99       Everyone        Medical      June 18, 2018
# 1407      100  Paid  39.99       Everyone        Medical      April 4, 2018
# 2629    1,000  Paid  37.99       Everyone      Lifestyle      July 18, 2017
# 2482    1,000  Paid  33.99       Everyone        Medical    October 2, 2017
#
#        Android_Ver
# 3946    4.1 and up
# 3221    4.4 and up
# 5765  4.0.3 and up
# 3145    4.4 and up
# 3114    4.2 and up
# 1331    7.0 and up
# 4606    4.0 and up
# 2461    4.1 and up
# 2394    4.1 and up
# 1946  4.0.3 and up
# 2775    1.6 and up
# 3554    4.4 and up
# 3897    4.2 and up
# 2193    4.0 and up
# 3856    4.3 and up
# 2282  4.0.3 and up
# 2281  4.0.3 and up
# 1407    4.1 and up
# 2629  4.0.3 and up
# 2482    4.0 and up

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean = df_apps_clean[df_apps_clean['Price'] < 250]
df_apps_clean.sort_values('Price', ascending=False).head()
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2282  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 2281  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407               LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2482    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
#
#      Installs  Type  Price Content_Rating     Genres     Last_Updated  \
# 2282    1,000  Paid  79.99       Everyone    Medical    June 18, 2018
# 2281    1,000  Paid  79.99       Everyone    Medical    June 18, 2018
# 1407      100  Paid  39.99       Everyone    Medical    April 4, 2018
# 2629    1,000  Paid  37.99       Everyone  Lifestyle    July 18, 2017
# 2482    1,000  Paid  33.99       Everyone    Medical  October 2, 2017
#
#        Android_Ver
# 2282  4.0.3 and up
# 2281  4.0.3 and up
# 1407    4.1 and up
# 2629  4.0.3 and up
# 2482    4.0 and up

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean["Installs"] = df_apps_clean["Installs"].astype(str).str.replace(',', '', regex=False)
df_apps_clean["Installs"] = pd.to_numeric(df_apps_clean["Installs"])

df_apps_clean['Revenue Estimate'] = df_apps_clean['Installs'].mul(df_apps_clean['Price'])
df_apps_clean.sort_values('Revenue Estimate', ascending=False).head()
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
# 9224                      Minecraft       FAMILY    4.50  2375336     19.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7478            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# 9220  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 9224  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 8825  10000000  Paid   0.99     Mature 17+                     Action
# 7151   1000000  Paid   6.99     Mature 17+                     Action
# 7478   1000000  Paid   5.99       Everyone                Photography
#
#         Last_Updated         Android_Ver  Revenue Estimate
# 9220   July 24, 2018  Varies with device     69,900,000.00
# 9224   July 24, 2018  Varies with device     69,900,000.00
# 8825   July 12, 2018          4.1 and up      9,900,000.00
# 7151  March 21, 2015          3.0 and up      6,990,000.00
# 7478   July 25, 2018          4.1 and up      5,990,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean.Category.nunique()
# Out:
# 33

# %%
top10_category = df_apps_clean.Category.value_counts()[:10]

# %%
top10_category
# Out:
# Category
# FAMILY             1743
# GAME               1097
# TOOLS               734
# PRODUCTIVITY        351
# MEDICAL             350
# COMMUNICATION       328
# SPORTS              319
# FINANCE             317
# PHOTOGRAPHY         317
# PERSONALIZATION     312
# Name: count, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
bar = px.bar(x = top10_category.index,
             y = top10_category.values)

bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="adf2eb06-f4aa-4a7d-b1cf-04ba343c0e65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adf2eb06-f4aa-4a7d-b1cf-04ba343c0e65")) {                    Plotly.newPlot(                        "adf2eb06-f4aa-4a7d-b1cf-04ba343c0e65",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["FAMILY","GAME","TOOLS","PRODUCTIVITY","MEDICAL","COMMUNICATION","SPORTS","FINANCE","PHOTOGRAPHY","PERSONALIZATION"],"xaxis":"x","y":[1743,1097,734,351,350,328,319,317,317,312],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2} ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

# %%
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')

h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5ef7fccc-ffc4-476d-8e31-bec7a79b1cc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ef7fccc-ffc4-476d-8e31-bec7a79b1cc7")) {                    Plotly.newPlot(                        "5ef7fccc-ffc4-476d-8e31-bec7a79b1cc7",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[15949410,26916200,31116110,53129800,53205576,56036100,62083000,124233100,168582000,264295110,273777750,426096500,537431120,724267560,871352000,876549400,1001768120,1583056220,1751131465,1921291655,2325341930,2869160000,3247831540,6221897200,6868859300,7496210650,10088243130,10257676490,11450724500,14069841475,14176070180,32647241530,35085862717],"xaxis":"x","y":["EVENTS","BEAUTY","PARENTING","AUTO_AND_VEHICLES","MEDICAL","COMICS","LIBRARIES_AND_DEMO","ART_AND_DESIGN","HOUSE_AND_HOME","DATING","FOOD_AND_DRINK","WEATHER","LIFESTYLE","MAPS_AND_NAVIGATION","EDUCATION","FINANCE","BUSINESS","HEALTH_AND_FITNESS","SPORTS","BOOKS_AND_REFERENCE","PERSONALIZATION","ENTERTAINMENT","SHOPPING","VIDEO_PLAYERS","TRAVEL_AND_LOCAL","NEWS_AND_MAGAZINES","PHOTOGRAPHY","FAMILY","TOOLS","SOCIAL","PRODUCTIVITY","COMMUNICATION","GAME"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555 ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
cat_number = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})
cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how="inner")
print(f'The dimensions of the DataFrame are: {cat_merged_df.shape}')
cat_merged_df.sort_values('Installs', ascending=False)

scatter = px.scatter(cat_merged_df,
                    x='App',
                    y='Installs',
                    title='Category Concentration',
                    size='App',
                    hover_name=cat_merged_df.index,
                    color='Installs')

scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))

scatter.show()
# Out:
# The dimensions of the DataFrame are: (33, 2)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="92dccf52-0dd1-49c0-ad9c-f8edd9261c02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92dccf52-0dd1-49c0-ad9c-f8edd9261c02")) {                    Plotly.newPlot(                        "92dccf52-0dd1-49c0-ad9c-f8edd9261c02",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eApp=%{marker.size}\u003cbr\u003eInstalls=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"legendgroup":"","marker":{"color":[124233100,53129800,26916200,1921291655,1001768120,56036100,32647241530,264295110,871352000,2869160000,15949410,10257676490,876549400,273777750,35085862717,1583056220,168582000,62083000,537431120,724267560,53205576,7496210650,31116110,2325341930,10088243130,14176070180,3247831540,14069841475,1751131465,11450724500,6868859300,6221897200,426096500],"coloraxis":"coloraxis","size":[62,73,42,178,303,58,328,195,155,149,45,1743,317,109,1097,297,76,65,310,124,350,233,50,312,317,351,238,259,319,734,226,160,75],"sizemode":"area","sizeref":4.3575,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[62,73,42,178,303,58,328,195,155,149,45,1743,317,109,1097,297,76,65,310,124,350,233,50,312,317,351,238,259,319,734,226,160,75],"xaxis":"x","y":[124233100,53129800,26916200,1921291655,1001768120,56036100,32647241530,264295110,871352000,2869160000,15949410,10257676490,876549400,273777750,35085862717,1583056220,168582000,62083000,537431120,724267560,53205576,7496210650,31116110,2325341930,10088243130,14176070180,3247831540,14069841475,1751131465,11450724500,6868859300,6221897200,426096500],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888 ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
print(f'We now have a single column with shape: {stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# We now have a single column with shape: (9833,)
# Number of genres: 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar = px.bar(x = num_genres.index[:15], # index = category name
             y = num_genres.values[:15], # count
             title='Top Genres',
             hover_name=num_genres.index[:15],
             color=num_genres.values[:15],
             color_continuous_scale='Agsunset')

bar.update_layout(xaxis_title='Genre',
yaxis_title='Number of Apps',
coloraxis_showscale=False)

bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b461d8a9-1659-4700-ac79-975daf759012" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b461d8a9-1659-4700-ac79-975daf759012")) {                    Plotly.newPlot(                        "b461d8a9-1659-4700-ac79-975daf759012",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Tools","Education","Entertainment","Action","Productivity","Medical","Sports","Communication","Photography","Finance","Personalization","Lifestyle","Business","Health & Fitness","Casual"],"legendgroup":"","marker":{"color":[734,670,573,375,351,350,337,329,317,317,312,311,303,299,262],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tools","Education","Entertainment","Action","Productivity","Medical","Sports","Communication","Photography","Finance","Personalization","Lifestyle","Business","Health & Fitness","Casual"],"xaxis":"x","y":[734,670,573,375,351,350,337,329,317,317,312,311,303,299,262],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outl ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   59
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
g_bar = px.bar(df_free_vs_paid,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')

g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))

g_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0e1d1e6c-7ac8-4c85-9863-f014bb2608cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e1d1e6c-7ac8-4c85-9863-f014bb2608cc")) {                    Plotly.newPlot(                        "0e1d1e6c-7ac8-4c85-9863-f014bb2608cc",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free\u003cbr\u003eCategory=%{x}\u003cbr\u003eApp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[59,72,42,170,292,58,306,191,151,147,45,1585,310,107,1020,285,76,65,297,119,262,231,48,246,299,333,236,257,297,671,218,156,68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=Paid\u003cbr\u003eCategory=%{x}\u003cbr\u003eApp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Paid","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paid","offsetgroup":"Paid","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BOOKS_AND_REFERENCE","BUSINESS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[3,1,8,11,22,4,4,2,158,7,2,77,12,13,5,88,2,2,66,18,18,2,2,22,63,8,4,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorba ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_apps_clean,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')

box.update_layout(yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ee8373c9-de32-484b-a11c-9e41f41e8e11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee8373c9-de32-484b-a11c-9e41f41e8e11")) {                    Plotly.newPlot(                        "ee8373c9-de32-484b-a11c-9e41f41e8e11",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Type=%{x}\u003cbr\u003eInstalls=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Free","marker":{"color":"#636efa"},"name":"Free","notched":true,"offsetgroup":"Free","orientation":"v","showlegend":true,"x":["Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free", ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = px.box(df_paid_apps,
             x='Category',
             y='Revenue Estimate',
             title='How Much Can Paid Apps Earn?')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))


box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b91e8059-4b6f-42b3-8a42-1f630fd90f60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b91e8059-4b6f-42b3-8a42-1f630fd90f60")) {                    Plotly.newPlot(                        "b91e8059-4b6f-42b3-8a42-1f630fd90f60",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eRevenue Estimate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","TOOLS","FAMILY","FAMILY","BUSINESS","BOOKS_AND_REFERENCE","FAMILY","FAMILY","FAMILY","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","GAME","PERSONALIZATION","FAMILY","FINANCE","SHOPPING","DATING","PERSONALIZATION","GAME","FAMILY","PRODUCTIVITY","FAMILY","MEDICAL","SPORTS","MEDICAL","PRODUCTIVITY","BUSINESS","PARENTING","LIFESTYLE","FAMILY","TOOLS","MAPS_AND_NAVIGATION","COMMUNICATION","PERSONALIZATION","COMMUNICATION","FAMILY","PERSONALIZATION","FAMILY","FAMILY","FAMILY","TOOLS","FAMILY","SPORTS","FAMILY","MEDICAL","MEDICAL","FAMILY","FAMILY","GAME","TOOLS","FAMILY","FAMILY","PERSONALIZATION","BOOKS_AND_REFERENCE","GAME","PERSONALIZATION","GAME","GAME","TOOLS","MEDICAL","TOOLS","TOOLS","PERSONALIZATION","GAME","COMMUNICATION","MEDICAL","SPORTS","PERSONALIZATION","COMMUNICATION","COMMUNICATION","PERSONALIZATION","TOOLS","PERSONALIZATION","PERSONALIZATION","PRODUCTIVITY","MEDICAL","FAMILY","TOOLS","TOOLS","BUSINESS","COMMUNICATION","FAMILY","PERSONALIZATION","PHOTOGRAPHY","MEDICAL","PERSONALIZATION","MEDICAL","COMMUNICATION","PRODUCTIVITY","BOOKS_AND_REFERENCE","TOOLS","WEATHER","FAMILY","FAMILY","MEDICAL","FAMILY","TOOLS","TOOLS","SPORTS","GAME","MEDICAL","PERSONALIZATION","PERSONALIZATION","NEWS_AND_MAGAZINES","COMMUNICATION","TOOLS","MEDICAL","FINANCE","FAMILY","PERSONALIZATION","PERSONALIZATION","MEDICAL","MEDICAL","FAMILY","MEDICAL","MEDICAL","FAMILY","FAMILY","FAMILY","FAMILY","GAME","PERSONALIZATION","TOOLS","PERSONALIZATION","GAME","GAME","GAME","FAMILY","FAMILY","PRODUCTIVITY","COMMUNICATION","SPORTS","SPORTS","FAMILY","MEDICAL","SPORTS","COMMUNICATION","LIFESTYLE","FAMILY","MEDICAL","MEDICAL","TOOLS","PRODUCTIVITY","FINANCE","HEALTH_AND_FITNESS","MEDICAL","PHOTOGRAPHY","FAMILY","FAMILY","PHOTOGRAPHY","SPORTS","ART_AND_DESIGN","FAMILY","PERSONALIZATION","PRODUCTIVITY","HEALTH_AND_FITNESS","MEDICAL","MEDICAL","TOOLS","PRODUCTIVITY","GAME","TOOLS","MEDICAL","LIFESTYLE","GAME","MEDICAL","MEDICAL","TRAVEL_AND_LOCAL","BUSINESS","MEDICAL","MEDICAL","COMMUNICATION","PERSONALIZATION","GAME","TRAVEL_AND_LOCAL","GAME","SPORTS","MEDICAL","MEDICAL","FAMILY","MEDICAL","TOOLS","BOOKS_AND_REFERENCE","FAMILY","MEDICAL","MEDICAL","MEDICAL","MEDICAL","GAME","BUSINESS","TOOLS","FAMILY","MEDICAL","MEDICAL","PERSONALIZATION","PHOTOGRAPHY","SPORTS","MAPS_AND_NAVIGATION","PERSONALIZATION","GAME","BOOKS_AND_REFERENCE","EDUCATION","FAMILY","FAMILY","FAMILY","SOCIAL","MEDICAL","TOOLS","SPORTS","FAMILY","FAMILY","TOOLS","WEATHER","VIDEO_PLAYERS","MEDICAL","MEDICAL","TOOLS","GAME","PERSONALIZATION","MEDICAL","LIFESTYLE","MEDICAL","DATING","HEALTH_AND_FITNESS","MEDICAL","FAMILY","PRODUCTIVITY","EDUCATION","SPORTS","FAMILY","PERSONALIZATION","PERSONALIZATION","FAMILY","GAME","FINANCE","GAME","MEDICAL","FAMILY","MEDICAL","MEDICAL","TOOLS","TOOLS","TOOLS","TOOLS","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","FAMILY","GAME","FAMILY" ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
df_paid_apps.Price.median()

# %%
box = px.box(df_paid_apps,
             x='Category',
             y="Price",
             title='Price per Category')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4ab701b5-13a5-4538-a912-95fcfe093d78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ab701b5-13a5-4538-a912-95fcfe093d78")) {                    Plotly.newPlot(                        "4ab701b5-13a5-4538-a912-95fcfe093d78",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY